# %% [markdown]
# <a href="https://colab.research.google.com/github/PaulaDiz/C-LCULO-NUM-RICO-II/blob/main/Ejercicio_secci%C3%B3n_5_2_1b_y_5_3_2c_Mar%C3%ADa_Barrio_y_Paula_Diz_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 def euler_method(f, x0, y0, N, x_end):
  h = (x_end - x0) / N # Tamaño del paso depende de N
  x_vals = [x0] # Lista para guardar los valores de x
  y_vals = [y0] # Lista para guardar los valores de y
  for i in range(N):
    y0 = y0 + h * f(x0, y0) # Fórmula del método de Euler
    x0 = x0 + h
    x_vals.append(x0)
    y_vals.append(y0)
  return x_vals, y_vals

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# Definir la función f(x, y) = dy/dx
def f(t, y):
  return 1+(t-y)**2 # Nueva ecuación: dy/dx = y - x^2 +

# %%
# Solución analítica exacta
def exact_solution(t):
  return t+(1/(1-t))

# %%
# Parámetros iniciales
a = 2 # Valor inicial de x
y0 =1 # Valor inicial de y
b = 3 # Valor final de x
h=0.5 # Número de subintervalos
N=(b-a)/h
N=round(N)
# Llamar al método de Euler
x_vals, y_vals = euler_method(f, a, y0, N, b)

# %%
# Calcular la solución exacta para los mismos valores de x
exact_vals = [exact_solution(t) for t in x_vals]
# Mostrar la tabla de resultados en formato de DataFrame
tabla_resultados = pd.DataFrame({
'x': x_vals,
'y (Euler)': y_vals,
'y (Exacta)': exact_vals
})
print(tabla_resultados)
# Graficar los resultados
plt.plot(x_vals, y_vals, label="Aproximación de Euler", marker='o')
plt.plot(x_vals, exact_vals, label="Solución Exacta", linestyle='--')
plt.xlabel("x")
plt.ylabel("y")
#plt.title(f"Método de Euler vs Solución Exacta: N = {N} subintervalos")
plt.legend()
plt.grid(True)
plt.show()
# Out:
#      x  y (Euler)  y (Exacta)
# 0  2.0      1.000    1.000000
# 1  2.5      2.000    1.833333
# 2  3.0      2.625    2.500000

# %%
import matplotlib.pyplot as plt
import pandas as pd
# Definir la nueva función f(t, y) = dy/dt
def f(t, y):
  return -y+t*y**(1/2) # Nueva ecuación:
# Definir la segunda derivada de f(t, y)
def f_prime(t, y):
  return -f(t, y) + y**(1/2)+t*(1/2)*y**(-1/2)*f(t,y) # Derivada:

# %%
# Método de Taylor de orden 2
def taylor_2nd_order(f, f_prime, t0, y0, N, t_end):
  h = (t_end - t0) / N # Tamaño del paso
  t_vals = [t0]
  y_vals = [y0]
  for i in range(N):
    y0 = y0 + h * f(t0, y0) + (h**2 / 2) * f_prime(t0, y0) # Método de Taylorde orden 2
    t0 = t0 + h
    t_vals.append(t0)
    y_vals.append(y0)
  return t_vals, y_vals

# %%
# Parámetros iniciales
t0 = 2 # Valor inicial de t
y0 = 2 # Valor inicial de y
t_end = 3 # Valor final de t
h=0.25
N=(b-a)/h
N=round(N)
# Llamar al método de Taylor de orden 2
t_vals, y_vals = taylor_2nd_order(f, f_prime, t0, y0, N, t_end)
# Calcular la solución exacta para los mismos valores de t
exact_vals = [exact_solution(t) for t in t_vals]
# Mostrar la tabla de resultados en formato de DataFrame
tabla_resultados = pd.DataFrame({
't': t_vals,
'y (Taylor 2do Orden)': y_vals,
'y (Exacta)': exact_vals
})
print(tabla_resultados)
# Graficar los resultados
plt.plot(t_vals, y_vals, label="Taylor 2do Orden", marker='o')
#plt.plot(t_vals, exact_vals, label="Solución Exacta", linestyle='--')
plt.xlabel("t")
plt.ylabel("y")
#plt.title(f"Método de Taylor de 2do Orden vs Solución Exacta: N = {N}
#subintervalos")
# Out:
#       t  y (Taylor 2do Orden)  y (Exacta)
# 0  2.00              2.000000    1.000000
# 1  2.25              2.243718    1.450000
# 2  2.50              2.563405    1.833333
# 3  2.75              2.963390    2.178571
# 4  3.00              3.448699    2.500000
# Text(0, 0.5, 'y')
